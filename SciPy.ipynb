# %% [markdown]
# # SciPy: algoritmos y métodos numéricos

# %% [markdown]
# ## Una introducción a SciPy

# %% [markdown]
# ## Álgebra lineal

# %% [markdown]
# ## Optimización

# %% [markdown]
# ## Integración numérica y solución de ecuaciones diferenciales ordinarias

# %% [markdown]
# ## Un poco de estadística
